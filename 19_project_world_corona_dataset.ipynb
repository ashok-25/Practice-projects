# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('world_corona_dataset.csv')
df.head()
# Out:
#          Date      Country  Confirmed  Recovered  Deaths
# 0  2020-01-22  Afghanistan          0          0       0
# 1  2020-01-22      Albania          0          0       0
# 2  2020-01-22      Algeria          0          0       0
# 3  2020-01-22      Andorra          0          0       0
# 4  2020-01-22       Angola          0          0       0

# %%
df.tail()
# Out:
#              Date             Country  Confirmed  Recovered  Deaths
# 23683  2020-05-26  West Bank and Gaza        429        365       3
# 23684  2020-05-26      Western Sahara          9          6       1
# 23685  2020-05-26               Yemen        249         10      49
# 23686  2020-05-26              Zambia        920        336       7
# 23687  2020-05-26            Zimbabwe         56         25       4

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.dtypes
# Out:
# Date         object
# Country      object
# Confirmed     int64
# Recovered     int64
# Deaths        int64
# dtype: object

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Date         datetime64[ns]
# Country              object
# Confirmed             int64
# Recovered             int64
# Deaths                int64
# dtype: object

# %%
df
# Out:
#             Date             Country  Confirmed  Recovered  Deaths
# 0     2020-01-22         Afghanistan          0          0       0
# 1     2020-01-22             Albania          0          0       0
# 2     2020-01-22             Algeria          0          0       0
# 3     2020-01-22             Andorra          0          0       0
# 4     2020-01-22              Angola          0          0       0
# ...          ...                 ...        ...        ...     ...
# 23683 2020-05-26  West Bank and Gaza        429        365       3
# 23684 2020-05-26      Western Sahara          9          6       1
# 23685 2020-05-26               Yemen        249         10      49
# 23686 2020-05-26              Zambia        920        336       7
# 23687 2020-05-26            Zimbabwe         56         25       4
#
# [23688 rows x 5 columns]

# %%
df.describe().T
# Out:
#              count         mean           std  min  25%   50%    75%  \
# Confirmed  23688.0  7969.367528  58421.090425  0.0  0.0  18.0  730.0
# Recovered  23688.0  2581.801714  15143.101257  0.0  0.0   1.0  123.0
# Deaths     23688.0   526.935030   3992.815956  0.0  0.0   0.0   13.0
#
#                  max
# Confirmed  1680913.0
# Recovered   384902.0
# Deaths       98913.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23688 entries, 0 to 23687
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       23688 non-null  datetime64[ns]
#  1   Country    23688 non-null  object
#  2   Confirmed  23688 non-null  int64
#  3   Recovered  23688 non-null  int64
#  4   Deaths     23688 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 925.4+ KB

# %%
df.Country.value_counts()
# Out:
# Kenya                    126
# Malaysia                 126
# Vietnam                  126
# Saudi Arabia             126
# Luxembourg               126
#                         ...
# Ethiopia                 126
# Sao Tome and Principe    126
# Uganda                   126
# Kosovo                   126
# Malta                    126
# Name: Country, Length: 188, dtype: int64

# %%
df.isnull().sum()
# Out:
# Date         0
# Country      0
# Confirmed    0
# Recovered    0
# Deaths       0
# dtype: int64

# %%
df.nunique()
# Out:
# Date          126
# Country       188
# Confirmed    5308
# Recovered    3303
# Deaths       1768
# dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x="Date",y='Confirmed',data=df)

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x="Date",y='Recovered',data=df)

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x="Date",y='Deaths',data=df)

# %%
for i in df.describe().columns:
    sns.boxplot(df[i])
    plt.show()

# %%
for i in df.describe().columns:
    sns.distplot(df[i])
    plt.show()

# %%
plt.figure(figsize=(50,10))
p=sns.lineplot(x="Country",y='Deaths',data=df)
p.set_xticklabels(labels=df['Country'].unique(),rotation=50)
# Out:
# [Text(0, 0, 'Afghanistan'),
#  Text(0, 0, 'Albania'),
#  Text(0, 0, 'Algeria'),
#  Text(0, 0, 'Andorra'),
#  Text(0, 0, 'Angola'),
#  Text(0, 0, 'Antigua and Barbuda'),
#  Text(0, 0, 'Argentina'),
#  Text(0, 0, 'Armenia'),
#  Text(0, 0, 'Australia'),
#  Text(0, 0, 'Austria'),
#  Text(0, 0, 'Azerbaijan'),
#  Text(0, 0, 'Bahamas'),
#  Text(0, 0, 'Bahrain'),
#  Text(0, 0, 'Bangladesh'),
#  Text(0, 0, 'Barbados'),
#  Text(0, 0, 'Belarus'),
#  Text(0, 0, 'Belgium'),
#  Text(0, 0, 'Belize'),
#  Text(0, 0, 'Benin'),
#  Text(0, 0, 'Bhutan'),
#  Text(0, 0, 'Bolivia'),
#  Text(0, 0, 'Bosnia and Herzegovina'),
#  Text(0, 0, 'Botswana'),
#  Text(0, 0, 'Brazil'),
#  Text(0, 0, 'Brunei'),
#  Text(0, 0, 'Bulgaria'),
#  Text(0, 0, 'Burkina Faso'),
#  Text(0, 0, 'Burma'),
#  Text(0, 0, 'Burundi'),
#  Text(0, 0, 'Cabo Verde'),
#  Text(0, 0, 'Cambodia'),
#  Text(0, 0, 'Cameroon'),
#  Text(0, 0, 'Canada'),
#  Text(0, 0, 'Central African Republic'),
#  Text(0, 0, 'Chad'),
#  Text(0, 0, 'Chile'),
# ...

# %%
plt.figure(figsize=(50,10))
p=sns.lineplot(x="Country",y='Recovered',data=df)
p.set_xticklabels(labels=df['Country'].unique(),rotation=50)
# Out:
# [Text(0, 0, 'Afghanistan'),
#  Text(0, 0, 'Albania'),
#  Text(0, 0, 'Algeria'),
#  Text(0, 0, 'Andorra'),
#  Text(0, 0, 'Angola'),
#  Text(0, 0, 'Antigua and Barbuda'),
#  Text(0, 0, 'Argentina'),
#  Text(0, 0, 'Armenia'),
#  Text(0, 0, 'Australia'),
#  Text(0, 0, 'Austria'),
#  Text(0, 0, 'Azerbaijan'),
#  Text(0, 0, 'Bahamas'),
#  Text(0, 0, 'Bahrain'),
#  Text(0, 0, 'Bangladesh'),
#  Text(0, 0, 'Barbados'),
#  Text(0, 0, 'Belarus'),
#  Text(0, 0, 'Belgium'),
#  Text(0, 0, 'Belize'),
#  Text(0, 0, 'Benin'),
#  Text(0, 0, 'Bhutan'),
#  Text(0, 0, 'Bolivia'),
#  Text(0, 0, 'Bosnia and Herzegovina'),
#  Text(0, 0, 'Botswana'),
#  Text(0, 0, 'Brazil'),
#  Text(0, 0, 'Brunei'),
#  Text(0, 0, 'Bulgaria'),
#  Text(0, 0, 'Burkina Faso'),
#  Text(0, 0, 'Burma'),
#  Text(0, 0, 'Burundi'),
#  Text(0, 0, 'Cabo Verde'),
#  Text(0, 0, 'Cambodia'),
#  Text(0, 0, 'Cameroon'),
#  Text(0, 0, 'Canada'),
#  Text(0, 0, 'Central African Republic'),
#  Text(0, 0, 'Chad'),
#  Text(0, 0, 'Chile'),
# ...

# %%
plt.figure(figsize=(50,10))
p=sns.lineplot(x="Country",y='Confirmed',data=df)
p.set_xticklabels(labels=df['Country'].unique(),rotation=50)
# Out:
# [Text(0, 0, 'Afghanistan'),
#  Text(0, 0, 'Albania'),
#  Text(0, 0, 'Algeria'),
#  Text(0, 0, 'Andorra'),
#  Text(0, 0, 'Angola'),
#  Text(0, 0, 'Antigua and Barbuda'),
#  Text(0, 0, 'Argentina'),
#  Text(0, 0, 'Armenia'),
#  Text(0, 0, 'Australia'),
#  Text(0, 0, 'Austria'),
#  Text(0, 0, 'Azerbaijan'),
#  Text(0, 0, 'Bahamas'),
#  Text(0, 0, 'Bahrain'),
#  Text(0, 0, 'Bangladesh'),
#  Text(0, 0, 'Barbados'),
#  Text(0, 0, 'Belarus'),
#  Text(0, 0, 'Belgium'),
#  Text(0, 0, 'Belize'),
#  Text(0, 0, 'Benin'),
#  Text(0, 0, 'Bhutan'),
#  Text(0, 0, 'Bolivia'),
#  Text(0, 0, 'Bosnia and Herzegovina'),
#  Text(0, 0, 'Botswana'),
#  Text(0, 0, 'Brazil'),
#  Text(0, 0, 'Brunei'),
#  Text(0, 0, 'Bulgaria'),
#  Text(0, 0, 'Burkina Faso'),
#  Text(0, 0, 'Burma'),
#  Text(0, 0, 'Burundi'),
#  Text(0, 0, 'Cabo Verde'),
#  Text(0, 0, 'Cambodia'),
#  Text(0, 0, 'Cameroon'),
#  Text(0, 0, 'Canada'),
#  Text(0, 0, 'Central African Republic'),
#  Text(0, 0, 'Chad'),
#  Text(0, 0, 'Chile'),
# ...

# %%
for i in df['Country'].unique():
    print(f'{i} : ',df[df['Country']==i].Deaths.max())
# Out:
# Afghanistan :  220
# Albania :  33
# Algeria :  617
# Andorra :  51
# Angola :  4
# Antigua and Barbuda :  3
# Argentina :  484
# Armenia :  91
# Australia :  103
# Austria :  643
# Azerbaijan :  52
# Bahamas :  11
# Bahrain :  14
# Bangladesh :  522
# Barbados :  7
# Belarus :  208
# Belgium :  9334
# Belize :  2
# Benin :  3
# Bhutan :  0
# Bolivia :  274
# Bosnia and Herzegovina :  149
# Botswana :  1
# Brazil :  24512
# Brunei :  1
# Bulgaria :  130
# Burkina Faso :  52
# Burma :  6
# Burundi :  1
# Cabo Verde :  4
# Cambodia :  0
# Cameroon :  175
# Canada :  6753
# Central African Republic :  1
# Chad :  62
# Chile :  806
# China :  4638
# Colombia :  776
# Comoros :  1
# Congo (Brazzaville) :  16
# Congo (Kinshasa) :  68
# Costa Rica :  10
# Cote d'Ivoire :  30
# Croatia :  101
# Cuba :  82
# Cyprus :  17
# Czechia :  317
# Denmark :  563
# Diamond Princess :  13
# Djibouti :  14
# Dominica :  0
# Dominican Republic :  468
# Ecuador :  3203
# Egypt :  797
# El Salvador :  36
# ...

# %% [markdown]
# we can see US,Spain,France and Brazil has max Deaths

# %%
for i in df['Country'].unique():
    print(f'{i} : ',df[df['Country']==i].Confirmed.max())
# Out:
# Afghanistan :  11831
# Albania :  1029
# Algeria :  8697
# Andorra :  763
# Angola :  70
# Antigua and Barbuda :  25
# Argentina :  13228
# Armenia :  7402
# Australia :  7139
# Austria :  16557
# Azerbaijan :  4403
# Bahamas :  100
# Bahrain :  9366
# Bangladesh :  36751
# Barbados :  92
# Belarus :  38059
# Belgium :  57455
# Belize :  18
# Benin :  339
# Bhutan :  27
# Bolivia :  7136
# Bosnia and Herzegovina :  2416
# Botswana :  35
# Brazil :  391222
# Brunei :  141
# Bulgaria :  2443
# Burkina Faso :  832
# Burma :  206
# Burundi :  42
# Cabo Verde :  390
# Cambodia :  124
# Cameroon :  5436
# Canada :  88090
# Central African Republic :  671
# Chad :  700
# Chile :  77961
# China :  84103
# Colombia :  23003
# Comoros :  87
# Congo (Brazzaville) :  487
# Congo (Kinshasa) :  2403
# Costa Rica :  956
# Cote d'Ivoire :  2477
# Croatia :  2244
# Cuba :  1963
# Cyprus :  939
# Czechia :  9050
# Denmark :  11627
# Diamond Princess :  712
# Djibouti :  2468
# Dominica :  16
# ...

# %% [markdown]
# we can see US,Spain,France,Germani and Brazil has max confirmed cases

# %%
for i in df['Country'].unique():
    print(f'{i} : ',df[df['Country']==i].Recovered.max())
# Out:
# Afghanistan :  1128
# Albania :  803
# Algeria :  4918
# Andorra :  676
# Angola :  18
# Antigua and Barbuda :  19
# Argentina :  4167
# Armenia :  3220
# Australia :  6560
# Austria :  15182
# Azerbaijan :  2819
# Bahamas :  46
# Bahrain :  4938
# Bangladesh :  7579
# Barbados :  71
# Belarus :  15086
# Belgium :  15320
# Belize :  16
# Benin :  118
# Bhutan :  6
# Bolivia :  677
# Bosnia and Herzegovina :  1721
# Botswana :  20
# Brazil :  158593
# Brunei :  137
# Bulgaria :  880
# Burkina Faso :  672
# Burma :  124
# Burundi :  20
# Cabo Verde :  155
# Cambodia :  122
# Cameroon :  1996
# Canada :  45352
# Central African Republic :  22
# Chad :  303
# Chile :  30915
# China :  79358
# Colombia :  5511
# Comoros :  21
# Congo (Brazzaville) :  147
# Congo (Kinshasa) :  340
# Costa Rica :  634
# Cote d'Ivoire :  1286
# Croatia :  2046
# Cuba :  1709
# Cyprus :  594
# Czechia :  6270
# Denmark :  10242
# Diamond Princess :  651
# Djibouti :  1079
# Dominica :  16
# ...

# %% [markdown]
# we can see US,Spain,France,Germani,Brazil,China,and india has max Recovered cases

# %%
plt.figure(figsize=(15,5))
p=sns.barplot(x="Date",y='Deaths',data=df)

# %%
plt.figure(figsize=(15,5))
p=sns.barplot(x="Date",y='Recovered',data=df)

# %%
plt.figure(figsize=(15,5))
p=sns.barplot(x="Date",y='Confirmed',data=df)

# %%
sns.pairplot(df)

# %%
corr=df.corr()

# %%
df
# Out:
#             Date             Country  Confirmed  Recovered  Deaths
# 0     2020-01-22         Afghanistan          0          0       0
# 1     2020-01-22             Albania          0          0       0
# 2     2020-01-22             Algeria          0          0       0
# 3     2020-01-22             Andorra          0          0       0
# 4     2020-01-22              Angola          0          0       0
# ...          ...                 ...        ...        ...     ...
# 23683 2020-05-26  West Bank and Gaza        429        365       3
# 23684 2020-05-26      Western Sahara          9          6       1
# 23685 2020-05-26               Yemen        249         10      49
# 23686 2020-05-26              Zambia        920        336       7
# 23687 2020-05-26            Zimbabwe         56         25       4
#
# [23688 rows x 5 columns]

# %% [markdown]
# # Data Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Country']=le.fit_transform(df['Country'])

# %%
df
# Out:
#             Date  Country  Confirmed  Recovered  Deaths
# 0     2020-01-22        0          0          0       0
# 1     2020-01-22        1          0          0       0
# 2     2020-01-22        2          0          0       0
# 3     2020-01-22        3          0          0       0
# 4     2020-01-22        4          0          0       0
# ...          ...      ...        ...        ...     ...
# 23683 2020-05-26      183        429        365       3
# 23684 2020-05-26      184          9          6       1
# 23685 2020-05-26      185        249         10      49
# 23686 2020-05-26      186        920        336       7
# 23687 2020-05-26      187         56         25       4
#
# [23688 rows x 5 columns]

# %% [markdown]
# # Macine learning

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
x=df.drop(['Date','Deaths'],axis=1)
x
# Out:
#        Country  Confirmed  Recovered
# 0            0          0          0
# 1            1          0          0
# 2            2          0          0
# 3            3          0          0
# 4            4          0          0
# ...        ...        ...        ...
# 23683      183        429        365
# 23684      184          9          6
# 23685      185        249         10
# 23686      186        920        336
# 23687      187         56         25
#
# [23688 rows x 3 columns]

# %%
y=df['Deaths']
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 23683     3
# 23684     1
# 23685    49
# 23686     7
# 23687     4
# Name: Deaths, Length: 23688, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=45)

# %%
x_train.shape
# Out:
# (17766, 3)

# %%
x_test.shape
# Out:
# (5922, 3)

# %%
y_train.shape
# Out:
# (17766,)

# %%
y_test.shape
# Out:
# (5922,)

# %%
lm=LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lm.score(x_train,y_train)
# Out:
# 0.8664102665054199

# %%
lm.coef_
# Out:
# array([0.0943583 , 0.06129365, 0.00771466])

# %%
lm.intercept_
# Out:
# 0.989416699465778

# %%
# predict the value
pred=lm.predict(x_test)
print("predicted Deaths : ",pred)
print('actual Deaths : ',y_test)
# Out:
# predicted Deaths :  [ 533.60543306 1122.64164151 1967.22185847 ...   32.3763503  1124.48845855
#    11.93497986]
# actual Deaths :  15119     288
# 22569     633
# 16012    1259
# 11308       0
# 9434        0
#          ...
# 9489        0
# 20693     239
# 10494       1
# 21947    1107
# 5756        0
# Name: Deaths, Length: 5922, dtype: int64

# %%
print("error : ")

print("Mean absolute error : ",mean_absolute_error(y_test,pred))
print("Mean squared error : ",mean_squared_error(y_test,pred))

print("Root mean squared error : ",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error :
# Mean absolute error :  271.7976700515709
# Mean squared error :  2300587.4213584173
# Root mean squared error :  1516.7687435329149

# %%
# r2 score
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# 0.862591980058951

# %% [markdown]
# # Regularization

# %%
from sklearn.linear_model import Lasso,Ridge
import matplotlib.pyplot as plt

# %%
ls=Lasso(alpha=0.0001)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
# Out:
# 0.8664102665054199

# %%
ls.coef_
# Out:
# array([0.09435827, 0.06129365, 0.00771466])

# %%
plt.bar(x.columns,ls.coef_)
# Out:
# <BarContainer object of 3 artists>

# %%
rd=Ridge(alpha=0.0001)
rd.fit(x_train,y_train)
rd.score(x_train,y_train)
# Out:
# 0.8664102665054199

# %%
rd.coef_
# Out:
# array([0.0943583 , 0.06129365, 0.00771466])

# %%
plt.bar(x.columns,rd.coef_)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# # Ensemble

# %%
from sklearn.ensemble import RandomForestRegressor
Rd=RandomForestRegressor()
Rd.fit(x_train,y_train)
rd_pred=Rd.predict(x_test)
print("Mean absolute error : ",mean_absolute_error(y_test,rd_pred))
print("Mean squared error : ",mean_squared_error(y_test,rd_pred))

print("Root mean squared error : ",np.sqrt(mean_squared_error(y_test,rd_pred)))
print('r2 score :',r2_score(y_test,rd_pred))
# Out:
# Mean absolute error :  46.750067541137895
# Mean squared error :  205991.53093376357
# Root mean squared error :  453.862898829331
# r2 score : 0.9876966690648422

# %% [markdown]
# We can see decreasing Root mean squared error in RandomForestRegressor

# %%
from sklearn.ensemble import AdaBoostRegressor

ad=AdaBoostRegressor()
ad.fit(x_train,y_train)
ad_predict=ad.predict(x_test)
print("Mean absolute error : ",mean_absolute_error(y_test,ad_predict))
print("Mean squared error : ",mean_squared_error(y_test,ad_predict))
print("Root mean squared error : ",np.sqrt(mean_squared_error(y_test,ad_predict)))
print('r2 score :',r2_score(y_test,ad_predict))
# Out:
# Mean absolute error :  252.17846881822305
# Mean squared error :  1241968.0205819039
# Root mean squared error :  1114.4361895514269
# r2 score : 0.9258205252476358

# %% [markdown]
# # Cross validation

# %%
from sklearn.model_selection import cross_val_score
lmscores= cross_val_score(lm,x,y,cv=10)
print(lmscores)
print(lmscores.mean(),lmscores.std())
# Out:
# [-2.97702042 -1.64414943 -0.14125823  0.15069118  0.56233867  0.66786026
#   0.80584077  0.85115466  0.87268124  0.87194397]
# 0.0020082671607482227 1.2355753269278078

# %% [markdown]
# # Saving the best model

# %% [markdown]
# RandomForestRegressor is giving less error

# %%
import joblib

# %%
joblib.dump(Rd,'coronamodelrd.ob')
# Out:
# ['coronamodelrd.ob']

# %%
random_forest_model=joblib.load('coronamodelrd.ob')

# %%
random_forest_model.predict(x_test)
# Out:
# array([4.34020e+02, 6.34970e+02, 1.25545e+03, ..., 1.06000e+00,
#        1.07511e+03, 0.00000e+00])
